# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# %cd src
# Out:
# [Errno 2] No such file or directory: 'src'
# /data/tma1/PyCharmProjects/Diffusion-Pullback/src
# /home/tma1/anaconda3/envs/Diffusion-Pullback/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
# !CUDA_VISIBLE_DEVICES=3 bash scripts/main_various_local_encoder_pullback_with_edit_prompt.sh
# Out:
# device : cuda:0, dtype : torch.float32
# is stable-diffusion
# /home/tma1/anaconda3/envs/Diffusion-Pullback/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# text_encoder/pytorch_model.fp16.safetensors not found
# Fetching 22 files: 100%|█████████████████████| 22/22 [00:00<00:00, 26715.31it/s]
# current experiment : idx : 0, op : mid, block_idx : 0, vis_num : 4, vis_num_pc : 2, pca_rank : 2, edit_prompt : curly hair
# start DDIMinversion
# start DDIMforward
# do_classifier_free_guidance :  False
# self.neg_prompt :
# self.for_prompt :
# t_start_idx :  0
# t_end_idx :  30
# !!!RUN LOCAL PULLBACK!!!
# Traceback (most recent call last):
#   File "/data/tma1/PyCharmProjects/Diffusion-Pullback/src/main.py", line 31, in <module>
# ...

# %%
img1 = '/data/jrobe187/Diffusion-Pullback/src/runs/Stable_Diffusion-Examples-with_prompt/results/x0_gen-Edit_zt-Examples_0-edit_0.7T-mid-block_0-pc_001_neg-edit_prompt_curly hair_multiple.png'
img2 = '/data/jrobe187/Diffusion-Pullback/src/runs/Stable_Diffusion-Examples-with_prompt/results/x0_gen-Edit_zt-Examples_0-edit_0.6T-mid-block_0-pc_001_neg-edit_prompt_curly hair_multiple.png'

# %%
img = mpimg.imread(img1)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
img = mpimg.imread(img2)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()
